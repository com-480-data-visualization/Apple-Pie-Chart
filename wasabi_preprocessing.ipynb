# %%
import pandas as pd
import pyarrow.parquet as pq
import pyarrow as pa
import ijson
import json
from decimal import Decimal

input_file = './json/song.json'
output_file = './json/song.parquet'

# Helper conversion functions
def convert_decimal(obj):
    if isinstance(obj, list):
        return [convert_decimal(i) for i in obj]
    elif isinstance(obj, dict):
        return {k: convert_decimal(v) for k, v in obj.items()}
    elif isinstance(obj, Decimal):
        return float(obj)
    else:
        return obj

# Explicit column casting
def enforce_types(df):
    # List columns to explicitly cast
    int_cols = ['rank', 'position']
    float_cols = ['confidence', 'duration', 'arousal_predicted', 'valence_predicted', 'gain', 'bpm']
    
    for col in int_cols:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce').astype('Int64')

    for col in float_cols:
        if col in df.columns:
            df[col] = pd.to_numeric(df[col], errors='coerce').astype(float)

    # Convert all complex objects explicitly to strings
    json_cols = ['deezer_mapping', 'chords_metadata', 'availableCountries', 'animux_paths']
    for col in json_cols:
        if col in df.columns:
            df[col] = df[col].apply(lambda x: json.dumps(x) if isinstance(x, (dict, list)) else x)
    
    return df

batch_size = 50000
batch = []
schema = None
writer = None

with open(input_file, 'rb') as f:
    parser = ijson.items(f, 'item')

    for i, record in enumerate(parser, 1):
        record = convert_decimal(record)
        batch.append(record)

        if i % batch_size == 0:
            df_batch = pd.json_normalize(batch)

            df_batch = enforce_types(df_batch)

            if schema is None:
                table = pa.Table.from_pandas(df_batch, preserve_index=False)
                schema = table.schema
                writer = pq.ParquetWriter(output_file, schema, compression='snappy')
            else:
                # Add missing columns with None values
                for col in schema.names:
                    if col not in df_batch.columns:
                        df_batch[col] = None
                df_batch = df_batch[schema.names]
                table = pa.Table.from_pandas(df_batch, schema=schema, preserve_index=False)

            writer.write_table(table)
            batch = []

    # Final batch
    if batch:
        df_batch = pd.json_normalize(batch)
        df_batch = enforce_types(df_batch)

        if schema is None:
            table = pa.Table.from_pandas(df_batch, preserve_index=False)
            schema = table.schema
            writer = pq.ParquetWriter(output_file, schema, compression='snappy')
        else:
            for col in schema.names:
                if col not in df_batch.columns:
                    df_batch[col] = None
            df_batch = df_batch[schema.names]
            table = pa.Table.from_pandas(df_batch, schema=schema, preserve_index=False)

        writer.write_table(table)

# Close writer explicitly
if writer:
    writer.close()

# %%
import pandas as pd
import ijson

input_file = './json/song.json'
output_file = './json/song.csv'

# Open JSON file as stream
with open(input_file, "rb") as f:
    objects = ijson.items(f, "item")  # Adjust 'item' if JSON is nested

    batch_size = 50000
    batch = []
    
    for i, obj in enumerate(objects, 1):
        batch.append(obj)
        
        if i % batch_size == 0:
            df = pd.json_normalize(batch)
            df.to_csv(output_file, mode="a", index=False, header=(i == batch_size))  # Append, write header only once
            batch = []

    if batch:  # Final batch
        df = pd.json_normalize(batch)
        df.to_csv(output_file, mode="a", index=False, header=False)

# %%
import polars as pl

df = pl.read_parquet('./json/song.parquet')

# %%
df.head()
# Out:
# shape: (5, 61)
# ┌──────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ position ┆ lengthAlbu ┆ urlSong   ┆ lyrics    ┆ … ┆ chords_me ┆ chords_me ┆ summary   ┆ id_album │
# │ ---      ┆ m          ┆ ---       ┆ ---       ┆   ┆ tadata.ch ┆ tadata._i ┆ ---       ┆ ---      │
# │ i64      ┆ ---        ┆ str       ┆ str       ┆   ┆ ordSequen ┆ d         ┆ list[str] ┆ str      │
# │          ┆ str        ┆           ┆           ┆   ┆ ce        ┆ ---       ┆           ┆          │
# │          ┆            ┆           ┆           ┆   ┆ ---       ┆ str       ┆           ┆          │
# │          ┆            ┆           ┆           ┆   ┆ list[stru ┆           ┆           ┆          │
# │          ┆            ┆           ┆           ┆   ┆ ct[3]]    ┆           ┆           ┆          │
# ╞══════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 0        ┆ 57:52      ┆ http://ly ┆ Turn it   ┆ … ┆ [{16.15," ┆ deezer:67 ┆ null      ┆ null     │
# │          ┆            ┆ rics.wiki ┆ up<br>I   ┆   ┆ Amaj",0.0 ┆ 354194    ┆           ┆          │
# │          ┆            ┆ a.com/A:T ┆ don&apos; ┆   ┆ }, {18.05 ┆           ┆           ┆          │
# │          ┆            ┆ urn…      ┆ t kno…    ┆   ┆ ,"D…      ┆           ┆           ┆          │
# │ 1        ┆ 57:52      ┆ http://ly ┆ Sick of   ┆ … ┆ [{1.65,"E ┆ deezer:67 ┆ null      ┆ null     │
# │          ┆            ┆ rics.wiki ┆ you, how  ┆   ┆ 7",0.0},  ┆ 354196    ┆           ┆          │
# │          ┆            ┆ a.com/A:F ┆ old do    ┆   ┆ {3.75,"Bm ┆           ┆           ┆          │
# │          ┆            ┆ ogh…      ┆ you th…   ┆   ┆ aj7…      ┆           ┆           ┆          │
# │ 2        ┆ 57:52      ┆ http://ly ┆ My name   ┆ … ┆ [{1.55,"E ┆ deezer:67 ┆ null      ┆ null     │
# │          ┆            ┆ rics.wiki ┆ is Jason< ┆   ┆ maj",0.0} ┆ 354198    ┆           ┆          │
# │          ┆            ┆ a.com/A:C ┆ br>I&apos ┆   ┆ , {2.35," ┆           ┆           ┆          │
# │          ┆            ┆ hee…      ┆ ;ll …     ┆   ┆ Dma…      ┆           ┆           ┆          │
# │ 3        ┆ 57:52      ┆ http://ly ┆ Got to    ┆ … ┆ [{4.65,"G ┆ deezer:67 ┆ null      ┆ null     │
# │          ┆            ┆ rics.wiki ┆ get out   ┆   ┆ min7",0.0 ┆ 354199    ┆           ┆          │
# │          ┆            ┆ a.com/A:N ┆ more<br>G ┆   ┆ }, {7.15, ┆           ┆           ┆          │
# │          ┆            ┆ o._…      ┆ et in …   ┆   ┆ "Bm…      ┆           ┆           ┆          │
# │ 4        ┆ 57:52      ┆ http://ly ┆ Bad idea  ┆ … ┆ [{1.75,"A ┆ deezer:67 ┆ null      ┆ null     │
# │          ┆            ┆ rics.wiki ┆ (x4) <br> ┆   ┆ maj7",0.0 ┆ 354200    ┆           ┆          │
# │          ┆            ┆ a.com/A:B ┆ <br>Ninet ┆   ┆ }, {4.55, ┆           ┆           ┆          │
# │          ┆            ┆ ad_…      ┆ y-n…      ┆   ┆ "Bm…      ┆           ┆           ┆          │
# └──────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
df.filter(pl.col('_id.$oid') == '60464733c2b2aa03d7e87a7e')
# Out:
# shape: (0, 61)
# ┌──────────┬─────────────┬─────────┬────────┬───┬─────────────┬─────────────┬───────────┬──────────┐
# │ position ┆ lengthAlbum ┆ urlSong ┆ lyrics ┆ … ┆ chords_meta ┆ chords_meta ┆ summary   ┆ id_album │
# │ ---      ┆ ---         ┆ ---     ┆ ---    ┆   ┆ data.chordS ┆ data._id    ┆ ---       ┆ ---      │
# │ i64      ┆ str         ┆ str     ┆ str    ┆   ┆ equence     ┆ ---         ┆ list[str] ┆ str      │
# │          ┆             ┆         ┆        ┆   ┆ ---         ┆ str         ┆           ┆          │
# │          ┆             ┆         ┆        ┆   ┆ list[struct ┆             ┆           ┆          │
# │          ┆             ┆         ┆        ┆   ┆ [3]]        ┆             ┆           ┆          │
# ╞══════════╪═════════════╪═════════╪════════╪═══╪═════════════╪═════════════╪═══════════╪══════════╡
# └──────────┴─────────────┴─────────┴────────┴───┴─────────────┴─────────────┴───────────┴──────────┘

# %%
import json
import pandas as pd

with open('./json/topic-models.json', 'rb') as f:
    data = json.load(f)

    df = pd.json_normalize(data)

df.drop(columns=['_id.$oid'], inplace=True)

df.to_csv('./json/topic-models.csv', index=False)

df.to_parquet('./json/topic-models.parquet')
df.head()
# Out:
#   topic_id                                              terms  \
# 0        0  [never, wish, miss, know, really, ve, have, ha...
# 1        1  [feel, fall, same, real, feeling, inside, when...
# 2        2  [too, stop, much, talk, house, listen, when, j...
# 3        3  [man, woman, chorus, lady, verse, u, dem, mi, ...
# 4        4  [could, world, change, remember, whole, see, w...
#
#                    _id.$oid
# 0  60464733c2b2aa03d7e87a7e
# 1  60464733c2b2aa03d7e87a7f
# 2  60464733c2b2aa03d7e87a80
# 3  60464733c2b2aa03d7e87a81
# 4  60464733c2b2aa03d7e87a82

# %%
with open('./json/song-topic.json', 'rb') as f:
    data = json.load(f)

df = pd.json_normalize(data)

df.drop(columns=['_id.$oid', 'song_id.$oid'], inplace=True)

display(df.head())

df.to_csv('./json/song-topic.csv', index=False)
df.to_parquet('./json/song-topic.parquet', compression='snappy')
# Out:
#                     id_song                                             topics
# 0  5714dec325ac0d8aee3804e7  [{'topic': '0', 'probability': '0.012696832'},...
# 1  5714dec325ac0d8aee3804e8  [{'topic': '0', 'probability': '0.0122550735'}...
# 2  5714dec325ac0d8aee3804e9  [{'topic': '2', 'probability': '0.013548387'},...
# 3  5714dec325ac0d8aee3804ea  [{'topic': '1', 'probability': '0.045793533'},...
# 4  5714dec325ac0d8aee3804eb  [{'topic': '0', 'probability': '0.011736132'},...

# %%
with open('./json/social-tags.json', 'rb') as f:
    data = json.load(f)

df = pd.json_normalize(data)

display(df.head())
df.to_csv('./json/social-tags.csv', index=False)
df.to_parquet('./json/social-tags.parquet')
# Out:
#             lastfm_id                                            socials  \
# 0  TRRRRCH128F9342C72  [{'social_tag': 'classic rock', 'nbr_tags': 10...
# 1  TRRRRMR128F145852B  [{'social_tag': 'pop', 'nbr_tags': 100}, {'soc...
# 2  TRRRRFU12903CB3A45  [{'social_tag': 'blues', 'nbr_tags': 100}, {'s...
# 3  TRRRRQS128F422EC78  [{'social_tag': 'love', 'nbr_tags': 100}, {'so...
# 4  TRRRRMN12903CAA3CB  [{'social_tag': 'rock', 'nbr_tags': 100}, {'so...
#
#                    _id.$oid              song_id.$oid
# 0  6042679fc2b2aa03d7e0e3e3  5714dee825ac0d8aee544a30
# 1  6042679fc2b2aa03d7e0e3e4  5714dedf25ac0d8aee4d9285
# 2  6042679fc2b2aa03d7e0e3ea  5714deca25ac0d8aee3d80a7
# 3  6042679fc2b2aa03d7e0e3ec  5714dec525ac0d8aee39cbff
# 4  6042679fc2b2aa03d7e0e3ee  5714dee525ac0d8aee5268a6

# %%
with open('./json/emotion-tags.json', 'rb') as f:
    data = json.load(f)

df = pd.json_normalize(data)

display(df.head())
df.to_csv('./json/emotion-tags.csv', index=False)
df.to_parquet('./json/emotion-tags.parquet')
# Out:
#             lastfm_id                                           emotions  \
# 0  TRRRRCH128F9342C72  [{'emotion_tag': 'happy', 'nbr_tags': 3}, {'em...
# 1  TRRRRNA128F42948D2          [{'emotion_tag': 'party', 'nbr_tags': 0}]
# 2  TRRRRYK128F93229FA  [{'emotion_tag': 'soothing', 'nbr_tags': 4}, {...
# 3  TRRRRGT128F4288741  [{'emotion_tag': 'smooth', 'nbr_tags': 66}, {'...
# 4  TRRRUFD12903CD7092      [{'emotion_tag': 'poignant', 'nbr_tags': 50}]
#
#                    _id.$oid              song_id.$oid
# 0  60426661c2b2aa03d7df9e94  5714dee825ac0d8aee544a30
# 1  60426661c2b2aa03d7df9e95  5714dec525ac0d8aee39fb93
# 2  60426661c2b2aa03d7df9e97  5714ded725ac0d8aee4751ea
# 3  60426661c2b2aa03d7df9e98  5714deeb25ac0d8aee564d9a
# 4  60426661c2b2aa03d7df9e99  5714ded225ac0d8aee43ff2d

# %%
with open('./json/artist-without-members.json', 'rb') as f:
    data = json.load(f)

df = pd.json_normalize(data)

display(df.head())
df.to_csv('./json/artist-without-members.csv', index=False)
# df.to_parquet('./json/artist-without-members.parquet')

# %%
with open('./json/artist-members.json', 'rb') as f:
    data = json.load(f)

df = pd.json_normalize(data)

display(df.head())
df.to_csv('./json/artist-members.csv', index=False)

# %%
with open('./json/album.json', 'rb') as f:
    data = json.load(f)

df = pd.json_normalize(data)

display(df.head())
df.to_csv('./json/album.csv', index=False)

# %%
import pandas as pd

df_song = pd.read_parquet('./csv/song.parquet')
df_song.head()
# Out:
#    position lengthAlbum                                  urlSong  \
# 0         0       57:52     http://lyrics.wikia.com/A:Turn_It_Up
# 1         1       57:52        http://lyrics.wikia.com/A:Foghorn
# 2         2       57:52  http://lyrics.wikia.com/A:Cheeky_Monkey
# 3         3       57:52          http://lyrics.wikia.com/A:No._1
# 4         4       57:52       http://lyrics.wikia.com/A:Bad_Idea
#
#                                               lyrics urlWikipedia  isClassic  \
# 0  Turn it up<br>I don&apos;t know where you&apos...                   False
# 1  Sick of you, how old do you think you are?<br>...                   False
# 2  My name is Jason<br>I&apos;ll rock yer face in...                   False
# 3  Got to get out more<br>Get in the place<br>Got...                   False
# 4  Bad idea (x4) <br><br>Ninety-nine per cent is ...                   False
#
#                                  urlAllmusic  \
# 0  http://www.allmusic.com/song/mt0013320473
# 1  http://www.allmusic.com/song/mt0013315202
# 2  http://www.allmusic.com/song/mt0013303555
# 3  http://www.allmusic.com/song/mt0013319228
# 4  http://www.allmusic.com/song/mt0031820543
#
#                                       urlMusicBrainz          title  \
# 0  http://musicbrainz.org/recording/3db608e4-eb72...     Turn It Up
# 1  http://musicbrainz.org/recording/84feea0c-187f...        Foghorn
# 2  http://musicbrainz.org/recording/f9303efd-b512...  Cheeky Monkey
# 3  http://musicbrainz.org/recording/52ef8537-c61d...          No. 1
# 4  http://musicbrainz.org/recording/53ae7abb-e5c8...       Bad Idea
#
#   publicationDateAlbum  ... valence valence_predicted  \
# 0                 1997  ...                  0.657853
# 1                 1997  ...                 -0.810233
# 2                 1997  ...                  0.223842
# 3                 1997  ...                 -0.016932
# 4                 1997  ...                  0.339134
#
#                    _id.$oid             id_album.$oid  \
# 0  5714dec325ac0d8aee3804e7  5714debb25ac0d8aee34d59a
# 1  5714dec325ac0d8aee3804e8  5714debb25ac0d8aee34d59a
# 2  5714dec325ac0d8aee3804e9  5714debb25ac0d8aee34d59a
# 3  5714dec325ac0d8aee3804ea  5714debb25ac0d8aee34d59a
# 4  5714dec325ac0d8aee3804eb  5714debb25ac0d8aee34d59a
#
#   chords_metadata.confidence  chords_metadata.duration  \
# 0                   0.746509                 93.023107
# 1                   0.807170                184.007596
# 2                   0.714021                216.007596
# 3                   0.767492                230.009229
# 4                   0.787385                141.010045
#
#                        chords_metadata.chordSequence  chords_metadata._id  \
# 0  [{'end': 16.150000000000002, 'label': 'Amaj', ...      deezer:67354194
# 1  [{'end': 1.6500000000000001, 'label': 'E7', 's...      deezer:67354196
# 2  [{'end': 1.55, 'label': 'Emaj', 'start': 0.0},...      deezer:67354198
# 3  [{'end': 4.65, 'label': 'Gmin7', 'start': 0.0}...      deezer:67354199
# 4  [{'end': 1.7500000000000002, 'label': 'Amaj7',...      deezer:67354200
#
#    summary id_album
# 0     None     None
# 1     None     None
# 2     None     None
# 3     None     None
# 4     None     None
#
# [5 rows x 61 columns]

# %%
columns_to_keep = ['_id.$oid',
                   'id_album.$oid',
                   'id_artist_deezer',
                   "title",
                   "publicationDate",
                   "language_detect",
                   "albumTitle",
                   "album_genre",
                   "publicationDateAlbum",
                   "bpm",
                   "gain",
                   'chords_metadata.chordSequence',
                   'chords_metadata.confidence',
                   'chords_metadata.duration',
                   'lyrics',
                   ]
df_song_new = df_song[columns_to_keep].copy()

# %%
df_song_new.rename(columns={'_id.$oid': 'song_id',
                            'id_album.$oid': 'album_id',
                            'albumTitle': 'album_title',
                            'album_genre': 'album_genre',
                            "publicationDate": "song_publication_date",
                            'publicationDateAlbum': 'album_publication_date',
                            'bpm': 'bpm',
                            'gain': 'gain',
                            'chords_metadata.chordSequence': 'chord_sequence',
                            'chords_metadata.confidence': 'chord_confidence',
                            'chords_metadata.duration': 'chord_duration',
                            'lyrics': 'lyrics',
                            }, inplace=True)

# %%
df_emotion = pd.read_csv('./csv/emotion-tags.csv')
df_emotion.drop(columns=['lastfm_id', '_id.$oid'], inplace=True)
df_emotion.rename(columns={'song_id.$oid': 'song_id'}, inplace=True)
df_song_emotion = pd.merge(df_song_new, df_emotion, on='song_id', how='left')
df_song_emotion
# Out:
#                           song_id                  album_id id_artist_deezer  \
# 0        5714dec325ac0d8aee3804e7  5714debb25ac0d8aee34d59a             3412
# 1        5714dec325ac0d8aee3804e8  5714debb25ac0d8aee34d59a             3412
# 2        5714dec325ac0d8aee3804e9  5714debb25ac0d8aee34d59a             3412
# 3        5714dec325ac0d8aee3804ea  5714debb25ac0d8aee34d59a             3412
# 4        5714dec325ac0d8aee3804eb  5714debb25ac0d8aee34d59a             3412
# ...                           ...                       ...              ...
# 2079505  57c92594e5c453a411c77445  57c92594e5c453a411c7734d             None
# 2079506  57c92594e5c453a411c77446  57c92594e5c453a411c7734d             None
# 2079507  57c92594e5c453a411c77447  57c92594e5c453a411c7734d             None
# 2079508  57c92594e5c453a411c77448  57c92594e5c453a411c7734d               13
# 2079509  57c92594e5c453a411c77449  57c92594e5c453a411c7734d             None
#
#                                                      title  \
# 0                                               Turn It Up
# 1                                                  Foghorn
# 2                                            Cheeky Monkey
# 3                                                    No. 1
# 4                                                 Bad Idea
# ...                                                    ...
# 2079505                                     Your Not Ready
# 2079506                  Eminem & 50 Cent:Jimmy Crack Corn
# 2079507                         Eminem & 50 Cent:The Re-Up
# 2079508  Eminem, 50 Cent, Ca$his & Lloyd Banks:You Don'...
# 2079509               Eminem, Obie Trice & 50 Cent:Love Me
#
#         song_publication_date language_detect            album_title  \
# 0                  1998-06-22         english  How Ace Are Buildings
# 1                  1998-06-22         english  How Ace Are Buildings
# 2                  1998-06-22         english  How Ace Are Buildings
# 3                  1998-06-22         english  How Ace Are Buildings
# 4                  1998-06-22         english  How Ace Are Buildings
# ...                       ...             ...                    ...
# 2079505                               english            Other Songs
# 2079506                               english            Other Songs
# 2079507                               english            Other Songs
# 2079508            2006-12-01         english            Other Songs
# 2079509                               english            Other Songs
#
#               album_genre album_publication_date    bpm  gain  \
# 0        Alternative Rock                   1997   77.0 -29.4
# 1        Alternative Rock                   1997  106.0 -10.6
# 2        Alternative Rock                   1997  185.0 -10.4
# 3        Alternative Rock                   1997   96.0 -10.6
# 4        Alternative Rock                   1997  101.0  -9.9
# ...                   ...                    ...    ...   ...
# 2079505                                             NaN   NaN
# 2079506                                             NaN   NaN
# 2079507                                             NaN   NaN
# 2079508                                           170.0  -6.8
# 2079509                                             NaN   NaN
#
#                                             chord_sequence  chord_confidence  \
# 0        [{'end': 16.150000000000002, 'label': 'Amaj', ...          0.746509
# 1        [{'end': 1.6500000000000001, 'label': 'E7', 's...          0.807170
# 2        [{'end': 1.55, 'label': 'Emaj', 'start': 0.0},...          0.714021
# 3        [{'end': 4.65, 'label': 'Gmin7', 'start': 0.0}...          0.767492
# 4        [{'end': 1.7500000000000002, 'label': 'Amaj7',...          0.787385
# ...                                                    ...               ...
# 2079505                                               None               NaN
# 2079506                                               None               NaN
# 2079507                                               None               NaN
# 2079508  [{'end': 2.65, 'label': 'Ebmin', 'start': 0.0}...          0.462999
# 2079509                                               None               NaN
#
#          chord_duration                                             lyrics  \
# 0             93.023107  Turn it up<br>I don&apos;t know where you&apos...
# 1            184.007596  Sick of you, how old do you think you are?<br>...
# 2            216.007596  My name is Jason<br>I&apos;ll rock yer face in...
# 3            230.009229  Got to get out more<br>Get in the place<br>Got...
# 4            141.010045  Bad idea (x4) <br><br>Ninety-nine per cent is ...
# ...                 ...                                                ...
# 2079505             NaN  [Young Buck] (chorus)<br><br>You not ready for...
# 2079506             NaN  [em &amp; 50]Man, lets go.<br>[eminem]hey yo f...
# 2079507             NaN  [Intro - Eminem] <br><br>[Beatboxing]  Yeah, w...
# 2079508      258.011429  [ Intro ]<br>Shady...Yeah..<br><br>Who run it?...
# 2079509             NaN  [Obie Trice] <br>You don&apos;t see me in the ...
#
#         emotions
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2079505      NaN
# 2079506      NaN
# 2079507      NaN
# 2079508      NaN
# 2079509      NaN
#
# [2079510 rows x 16 columns]

# %%
df_topics = pd.read_parquet('./csv/song-topic.parquet')
df_topics.rename(columns={'id_song': 'song_id'}, inplace=True)
df_song_emotion_topics = pd.merge(df_song_emotion, df_topics, on='song_id', how='left')
df_song_emotion_topics
# Out:
#                           song_id                  album_id id_artist_deezer  \
# 0        5714dec325ac0d8aee3804e7  5714debb25ac0d8aee34d59a             3412
# 1        5714dec325ac0d8aee3804e8  5714debb25ac0d8aee34d59a             3412
# 2        5714dec325ac0d8aee3804e9  5714debb25ac0d8aee34d59a             3412
# 3        5714dec325ac0d8aee3804ea  5714debb25ac0d8aee34d59a             3412
# 4        5714dec325ac0d8aee3804eb  5714debb25ac0d8aee34d59a             3412
# ...                           ...                       ...              ...
# 2079505  57c92594e5c453a411c77445  57c92594e5c453a411c7734d             None
# 2079506  57c92594e5c453a411c77446  57c92594e5c453a411c7734d             None
# 2079507  57c92594e5c453a411c77447  57c92594e5c453a411c7734d             None
# 2079508  57c92594e5c453a411c77448  57c92594e5c453a411c7734d               13
# 2079509  57c92594e5c453a411c77449  57c92594e5c453a411c7734d             None
#
#                                                      title  \
# 0                                               Turn It Up
# 1                                                  Foghorn
# 2                                            Cheeky Monkey
# 3                                                    No. 1
# 4                                                 Bad Idea
# ...                                                    ...
# 2079505                                     Your Not Ready
# 2079506                  Eminem & 50 Cent:Jimmy Crack Corn
# 2079507                         Eminem & 50 Cent:The Re-Up
# 2079508  Eminem, 50 Cent, Ca$his & Lloyd Banks:You Don'...
# 2079509               Eminem, Obie Trice & 50 Cent:Love Me
#
#         song_publication_date language_detect            album_title  \
# 0                  1998-06-22         english  How Ace Are Buildings
# 1                  1998-06-22         english  How Ace Are Buildings
# 2                  1998-06-22         english  How Ace Are Buildings
# 3                  1998-06-22         english  How Ace Are Buildings
# 4                  1998-06-22         english  How Ace Are Buildings
# ...                       ...             ...                    ...
# 2079505                               english            Other Songs
# 2079506                               english            Other Songs
# 2079507                               english            Other Songs
# 2079508            2006-12-01         english            Other Songs
# 2079509                               english            Other Songs
#
#               album_genre album_publication_date    bpm  gain  \
# 0        Alternative Rock                   1997   77.0 -29.4
# 1        Alternative Rock                   1997  106.0 -10.6
# 2        Alternative Rock                   1997  185.0 -10.4
# 3        Alternative Rock                   1997   96.0 -10.6
# 4        Alternative Rock                   1997  101.0  -9.9
# ...                   ...                    ...    ...   ...
# 2079505                                             NaN   NaN
# 2079506                                             NaN   NaN
# 2079507                                             NaN   NaN
# 2079508                                           170.0  -6.8
# 2079509                                             NaN   NaN
#
#                                             chord_sequence  chord_confidence  \
# 0        [{'end': 16.150000000000002, 'label': 'Amaj', ...          0.746509
# 1        [{'end': 1.6500000000000001, 'label': 'E7', 's...          0.807170
# 2        [{'end': 1.55, 'label': 'Emaj', 'start': 0.0},...          0.714021
# 3        [{'end': 4.65, 'label': 'Gmin7', 'start': 0.0}...          0.767492
# 4        [{'end': 1.7500000000000002, 'label': 'Amaj7',...          0.787385
# ...                                                    ...               ...
# 2079505                                               None               NaN
# 2079506                                               None               NaN
# 2079507                                               None               NaN
# 2079508  [{'end': 2.65, 'label': 'Ebmin', 'start': 0.0}...          0.462999
# 2079509                                               None               NaN
#
#          chord_duration                                             lyrics  \
# 0             93.023107  Turn it up<br>I don&apos;t know where you&apos...
# 1            184.007596  Sick of you, how old do you think you are?<br>...
# 2            216.007596  My name is Jason<br>I&apos;ll rock yer face in...
# 3            230.009229  Got to get out more<br>Get in the place<br>Got...
# 4            141.010045  Bad idea (x4) <br><br>Ninety-nine per cent is ...
# ...                 ...                                                ...
# 2079505             NaN  [Young Buck] (chorus)<br><br>You not ready for...
# 2079506             NaN  [em &amp; 50]Man, lets go.<br>[eminem]hey yo f...
# 2079507             NaN  [Intro - Eminem] <br><br>[Beatboxing]  Yeah, w...
# 2079508      258.011429  [ Intro ]<br>Shady...Yeah..<br><br>Who run it?...
# 2079509             NaN  [Obie Trice] <br>You don&apos;t see me in the ...
#
#         emotions                                             topics
# 0            NaN  [{'probability': '0.012696832', 'topic': '0'},...
# 1            NaN  [{'probability': '0.0122550735', 'topic': '0'}...
# 2            NaN  [{'probability': '0.013548387', 'topic': '2'},...
# 3            NaN  [{'probability': '0.045793533', 'topic': '1'},...
# 4            NaN  [{'probability': '0.011736132', 'topic': '0'},...
# ...          ...                                                ...
# 2079505      NaN  [{'probability': '0.018409366', 'topic': '2'},...
# 2079506      NaN                                                NaN
# 2079507      NaN                                                NaN
# 2079508      NaN                                                NaN
# 2079509      NaN                                                NaN
#
# [2079510 rows x 17 columns]

# %%
df_aritist_without_members = pd.read_csv('./csv/artist-without-members.csv')
df_aritist_without_members = df_aritist_without_members[["_id.$oid", 'id_artist_deezer', 'name', 'locationInfo', "type", "gender"]]
df_aritist_without_members.rename(columns={'_id.$oid': 'artist_id',
                                           'name': 'artist_name',
                                           'locationInfo': "artist_location",
                                           'type': 'artist_type',
                                           'gender': 'artist_gender'}, inplace=True)
df_aritist_without_members.to_csv('./proc/artist.csv', index=False)
# Out:
# /tmp/ipykernel_2395570/4189181621.py:1: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_aritist_without_members = pd.read_csv('./csv/artist-without-members.csv')

# %%
df_aritist_without_members
# Out:
#                       artist_id  id_artist_deezer          artist_name  \
# 0      56d7e91b6b60c09814f93e4a            3412.0                    A
# 1      56d7e91c6b60c09814f93e4c               NaN        A (エース) (ACE)
# 2      56d7e91d6b60c09814f93e4e          242156.0          A Balladeer
# 3      56d7e91e6b60c09814f93e50         4708137.0  A Beautiful Silence
# 4      56d7e91e6b60c09814f93e52         1006041.0   A Band Called Pain
# ...                         ...               ...                  ...
# 77487  56d997b1cc2ddd0c0f6bf2d2           96732.0                 Zara
# 77488  56d997b3cc2ddd0c0f6bf2d3           66370.0                Zebra
# 77489  56d997b3cc2ddd0c0f6bf2d4         4098622.0      Zebra & Giraffe
# 77490  56d997b3cc2ddd0c0f6bf2d5               NaN               Zearle
# 77491  56d997b6cc2ddd0c0f6bf2d6               NaN        Zecchino DOro
#
#                                   artist_location artist_type artist_gender
# 0          ['England', 'West Yorkshire', 'Leeds']       Group           NaN
# 1                                       ['Japan']       Group           NaN
# 2                                              []       Group           NaN
# 3      ['United States', 'Michigan', 'Marquette']         NaN           NaN
# 4      ['United States', 'California', 'Oakland']       Group           NaN
# ...                                           ...         ...           ...
# 77487    ['Turkey', 'Marmara Region', 'Istanbul']      Person           NaN
# 77488                           ['United States']       Group           NaN
# 77489                 ['South Africa', 'Gauteng']       Group           NaN
# 77490               ['United States', 'Missouri']      Person           NaN
# 77491                                          []         NaN           NaN
#
# [77492 rows x 6 columns]

# %%
df_album = pd.read_csv('./csv/album.csv')
df_album = df_album[["_id.$oid", 'title', "id_artist.$oid", 'publicationDate', "length", "genre", "country"]]
df_album.rename(columns={'_id.$oid': 'album_id', 'id_artist.$oid': 'artist_id', 'title': 'title', 'publicationDate': 'publication_date'}, inplace=True)
df_album.to_csv('./proc/album.csv', index=False)
# Out:
# /tmp/ipykernel_2395570/2117869795.py:1: DtypeWarning: Columns (7,17,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_album = pd.read_csv('./csv/album.csv')

# %%
df_album
# Out:
#                         album_id                    title  \
# 0       5714debb25ac0d8aee34d59a    How Ace Are Buildings
# 1       5714debb25ac0d8aee34d59b        A Vs. Monkey Kong
# 2       5714debb25ac0d8aee34d59c            Hi-Fi Serious
# 3       5714debb25ac0d8aee34d59d     Teen Dance Ordinance
# 4       5714debb25ac0d8aee34d59e         Non-Album Tracks
# ...                          ...                      ...
# 208738  57c92594e5c453a411c77328    5 (Murder By Numbers)
# 208739  57c92594e5c453a411c77333          Animal Ambition
# 208740  57c92594e5c453a411c77342     Street King Immortal
# 208741  57c92594e5c453a411c77348  Songs Featuring 50 Cent
# 208742  57c92594e5c453a411c7734d              Other Songs
#
#                        artist_id publication_date length             genre  \
# 0       56d7e91b6b60c09814f93e4a             1997  57:52  Alternative Rock
# 1       56d7e91b6b60c09814f93e4a             1999  50:29  Alternative Rock
# 2       56d7e91b6b60c09814f93e4a             2002  45:36  Alternative Rock
# 3       56d7e91b6b60c09814f93e4a             2005  47:30  Alternative Rock
# 4       56d7e91b6b60c09814f93e4a              NaN    NaN               NaN
# ...                          ...              ...    ...               ...
# 208738  57c92593e5c453a411c77256             2012  31:29           Hip Hop
# 208739  57c92593e5c453a411c77256             2014  39:14           Hip Hop
# 208740  57c92593e5c453a411c77256             2014    NaN               NaN
# 208741  57c92593e5c453a411c77256              NaN    NaN               NaN
# 208742  57c92593e5c453a411c77256              NaN    NaN               NaN
#
#        country
# 0           GB
# 1           GB
# 2           GB
# 3           GB
# 4          NaN
# ...        ...
# 208738      US
# 208739     NaN
# 208740     NaN
# 208741     NaN
# 208742     NaN
#
# [208743 rows x 7 columns]

# %%
df_song_emotion_topics.columns
# Out:
# Index(['song_id', 'album_id', 'id_artist_deezer', 'title',
#        'song_publication_date', 'language_detect', 'album_title',
#        'album_genre', 'album_publication_date', 'bpm', 'gain',
#        'chord_sequence', 'chord_confidence', 'chord_duration', 'lyrics',
#        'emotions', 'topics'],
#       dtype='object')

# %%
df_song_emotion_topics_album = pd.merge(df_song_emotion_topics, df_album, on='album_id', how='left')

# %%
df_song_emotion_topics_album.columns
# Out:
# Index(['song_id', 'album_id', 'id_artist_deezer', 'title_x',
#        'song_publication_date', 'language_detect', 'album_title',
#        'album_genre', 'album_publication_date', 'bpm', 'gain',
#        'chord_sequence', 'chord_confidence', 'chord_duration', 'lyrics',
#        'emotions', 'topics', 'title_y', 'artist_id', 'publication_date',
#        'length', 'genre', 'country'],
#       dtype='object')

# %%
df_song_emotion_topics_album_artist = pd.merge(df_song_emotion_topics_album, df_aritist_without_members, on='artist_id', how='left')

# %%
df_song_emotion_topics_album_artist.columns
# Out:
# Index(['song_id', 'album_id', 'id_artist_deezer_x', 'title_x',
#        'song_publication_date', 'language_detect', 'album_title',
#        'album_genre', 'album_publication_date', 'bpm', 'gain',
#        'chord_sequence', 'chord_confidence', 'chord_duration', 'lyrics',
#        'emotions', 'topics', 'title_y', 'artist_id', 'publication_date',
#        'length', 'genre', 'country', 'id_artist_deezer_y', 'artist_name',
#        'artist_location', 'artist_type', 'artist_gender'],
#       dtype='object')

# %%
df_song_emotion_topics_album_artist.drop(columns=['id_artist_deezer_x', 'id_artist_deezer_y'], inplace=True)

# %%
df_song_emotion_topics_album_artist.drop(columns=['title_y', 'publication_date', 'genre'], inplace=True)

# %%
df_song_emotion_topics_album_artist.columns
# Out:
# Index(['song_id', 'album_id', 'title_x', 'song_publication_date',
#        'language_detect', 'album_title', 'album_genre',
#        'album_publication_date', 'bpm', 'gain', 'chord_sequence',
#        'chord_confidence', 'chord_duration', 'lyrics', 'emotions', 'topics',
#        'artist_id', 'length', 'country', 'artist_name', 'artist_location',
#        'artist_type', 'artist_gender'],
#       dtype='object')

# %%
df_song_emotion_topics_album_artist.rename(columns={'title_x': 'song_title',
                                                    'length': 'album_length',
                                                    'country': 'album_country'}, inplace=True)

# %%
columns = ['song_id', 'song_title', 'song_publication_date', 'language_detect', 'bpm', 'gain', 'chord_sequence', 'chord_confidence', 'chord_duration', 'lyrics', 'emotions', 'topics',
            'artist_id', 'artist_name', 'artist_location', 'artist_type', 'artist_gender',
            'album_id', 'album_title', 'album_genre','album_publication_date','album_length', 'album_country']
df_song_emotion_topics_album_artist = df_song_emotion_topics_album_artist[columns]
df_song_emotion_topics_album_artist.head()
# Out:
#                     song_id     song_title song_publication_date  \
# 0  5714dec325ac0d8aee3804e7     Turn It Up            1998-06-22
# 1  5714dec325ac0d8aee3804e8        Foghorn            1998-06-22
# 2  5714dec325ac0d8aee3804e9  Cheeky Monkey            1998-06-22
# 3  5714dec325ac0d8aee3804ea          No. 1            1998-06-22
# 4  5714dec325ac0d8aee3804eb       Bad Idea            1998-06-22
#
#   language_detect    bpm  gain  \
# 0         english   77.0 -29.4
# 1         english  106.0 -10.6
# 2         english  185.0 -10.4
# 3         english   96.0 -10.6
# 4         english  101.0  -9.9
#
#                                       chord_sequence  chord_confidence  \
# 0  [{'end': 16.150000000000002, 'label': 'Amaj', ...          0.746509
# 1  [{'end': 1.6500000000000001, 'label': 'E7', 's...          0.807170
# 2  [{'end': 1.55, 'label': 'Emaj', 'start': 0.0},...          0.714021
# 3  [{'end': 4.65, 'label': 'Gmin7', 'start': 0.0}...          0.767492
# 4  [{'end': 1.7500000000000002, 'label': 'Amaj7',...          0.787385
#
#    chord_duration                                             lyrics  ...  \
# 0       93.023107  Turn it up<br>I don&apos;t know where you&apos...  ...
# 1      184.007596  Sick of you, how old do you think you are?<br>...  ...
# 2      216.007596  My name is Jason<br>I&apos;ll rock yer face in...  ...
# 3      230.009229  Got to get out more<br>Get in the place<br>Got...  ...
# 4      141.010045  Bad idea (x4) <br><br>Ninety-nine per cent is ...  ...
#
#   artist_name                         artist_location artist_type  \
# 0           A  ['England', 'West Yorkshire', 'Leeds']       Group
# 1           A  ['England', 'West Yorkshire', 'Leeds']       Group
# 2           A  ['England', 'West Yorkshire', 'Leeds']       Group
# 3           A  ['England', 'West Yorkshire', 'Leeds']       Group
# 4           A  ['England', 'West Yorkshire', 'Leeds']       Group
#
#   artist_gender                  album_id            album_title  \
# 0           NaN  5714debb25ac0d8aee34d59a  How Ace Are Buildings
# 1           NaN  5714debb25ac0d8aee34d59a  How Ace Are Buildings
# 2           NaN  5714debb25ac0d8aee34d59a  How Ace Are Buildings
# 3           NaN  5714debb25ac0d8aee34d59a  How Ace Are Buildings
# 4           NaN  5714debb25ac0d8aee34d59a  How Ace Are Buildings
#
#         album_genre album_publication_date album_length album_country
# 0  Alternative Rock                   1997        57:52            GB
# 1  Alternative Rock                   1997        57:52            GB
# 2  Alternative Rock                   1997        57:52            GB
# 3  Alternative Rock                   1997        57:52            GB
# 4  Alternative Rock                   1997        57:52            GB
#
# [5 rows x 23 columns]

# %%
df_song_emotion_topics_album_artist.to_csv('./proc/song.csv', index=False)
df_song_emotion_topics_album_artist.to_parquet('./proc/song.parquet')
